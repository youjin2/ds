# %%
import sys
sys.path.append("../")

# %%
import os

import pandas as pd
import shap
import xgboost
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Config

# %%
dataset_path = os.path.abspath("../data/boston_house_price.csv")

# %% [markdown]
# ## Load Dataset
# ### Description
# The Boston Housing Dataset
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per \$10,000
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - \% lower status of the population
# - MEDV - Median value of owner-occupied homes in \$1000's
#
# ### Reference
# https://www.kaggle.com/code/prasadperera/the-boston-housing-dataset

# %%
data = pd.read_csv(dataset_path)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.shape
# Out:
# (506, 14)

# %% [markdown]
# ## Explore Data Analysis

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
"""
Historgram for each feature
"""

fig, axes = plt.subplots(2, 7)
cols = data.columns
for i, col in enumerate(cols):
    rn, cn = divmod(i, 7)
    ax = axes[rn, cn]
    ax.hist(data[col], bins=20, edgecolor="white", density=True)
    ax.grid(linestyle=":")
    ax.set_xlabel(col)
    ax.set_ylabel("Probability")

fig.subplots_adjust(right=2, wspace=0.7, hspace=0.5)

# %%
"""
Correlation between features
"""

corr_mat = data.corr()
corr_mat.style.background_gradient(cmap="RdBu_r", vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_3fe9d_row0_col0, #T_3fe9d_row1_col1, #T_3fe9d_row2_col2, #T_3fe9d_row3_col3, #T_3fe9d_row4_col4, #T_3fe9d_row5_col5, #T_3fe9d_row6_col6, #T_3fe9d_row7_col7, #T_3fe9d_row8_col8, #T_3fe9d_row9_col9, #T_3fe9d_row10_col10, #T_3fe9d_row11_col11, #T_3fe9d_row12_col12, #T_3fe9d_row13_col13 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_3fe9d_row0_col1, #T_3fe9d_row1_col0 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_3fe9d_row0_col2, #T_3fe9d_row2_col0 {
#   background-color: #f2a17f;
#   color: #000000;
# }
# #T_3fe9d_row0_col3, #T_3fe9d_row3_col0 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_3fe9d_row0_col4, #T_3fe9d_row4_col0 {
#   background-color: #f19e7d;
#   color: #000000;
# }
# #T_3fe9d_row0_col5, #T_3fe9d_row5_col0 {
#   background-color: #cae1ee;
#   color: #000000;
# }
# #T_3fe9d_row0_col6, #T_3fe9d_row6_col0 {
#   background-color: #f6b191;
#   color: #000000;
# }
# #T_3fe9d_row0_col7, #T_3fe9d_row4_col11, #T_3fe9d_row6_col13, #T_3fe9d_row7_col0, #T_3fe9d_row8_col13, #T_3fe9d_row11_col4, #T_3fe9d_row13_col6, #T_3fe9d_row13_col8 {
#   background-color: #98c8e0;
#   color: #000000;
# }
# #T_3fe9d_row0_col8, #T_3fe9d_row8_col0 {
#   background-color: #d05548;
#   color: #f1f1f1;
# }
# #T_3fe9d_row0_col9, #T_3fe9d_row9_col0 {
#   background-color: #d86551;
#   color: #f1f1f1;
# }
# #T_3fe9d_row0_col10, #T_3fe9d_row7_col11, #T_3fe9d_row10_col0, #T_3fe9d_row11_col7 {
#   background-color: #f9c2a7;
#   color: #000000;
# }
# #T_3fe9d_row0_col11, #T_3fe9d_row0_col13, #T_3fe9d_row11_col0, #T_3fe9d_row13_col0 {
#   background-color: #96c7df;
#   color: #000000;
# }
# #T_3fe9d_row0_col12, #T_3fe9d_row6_col8, #T_3fe9d_row8_col6, #T_3fe9d_row9_col10, #T_3fe9d_row10_col9, #T_3fe9d_row12_col0 {
#   background-color: #eb9172;
#   color: #f1f1f1;
# }
# #T_3fe9d_row1_col2, #T_3fe9d_row2_col1, #T_3fe9d_row7_col9, #T_3fe9d_row9_col7 {
#   background-color: #5ca3cb;
#   color: #f1f1f1;
# }
# #T_3fe9d_row1_col3, #T_3fe9d_row3_col1 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_3fe9d_row1_col4, #T_3fe9d_row4_col1 {
#   background-color: #62a7ce;
#   color: #f1f1f1;
# }
# #T_3fe9d_row1_col5, #T_3fe9d_row5_col1 {
#   background-color: #f8bda1;
#   color: #000000;
# }
# #T_3fe9d_row1_col6, #T_3fe9d_row6_col1 {
#   background-color: #4f9bc7;
#   color: #f1f1f1;
# }
# #T_3fe9d_row1_col7, #T_3fe9d_row4_col9, #T_3fe9d_row7_col1, #T_3fe9d_row9_col4 {
#   background-color: #c94741;
#   color: #f1f1f1;
# }
# #T_3fe9d_row1_col8, #T_3fe9d_row8_col1 {
#   background-color: #aed3e6;
#   color: #000000;
# }
# #T_3fe9d_row1_col9, #T_3fe9d_row9_col1 {
#   background-color: #acd2e5;
#   color: #000000;
# }
# #T_3fe9d_row1_col10, #T_3fe9d_row2_col5, #T_3fe9d_row5_col2, #T_3fe9d_row10_col1 {
#   background-color: #93c6de;
#   color: #000000;
# }
# #T_3fe9d_row1_col11, #T_3fe9d_row3_col13, #T_3fe9d_row11_col1, #T_3fe9d_row13_col3 {
#   background-color: #fcdecd;
#   color: #000000;
# }
# #T_3fe9d_row1_col12, #T_3fe9d_row12_col1 {
#   background-color: #8dc2dc;
#   color: #000000;
# }
# #T_3fe9d_row1_col13, #T_3fe9d_row13_col1 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_3fe9d_row2_col3, #T_3fe9d_row3_col2 {
#   background-color: #f9eee7;
#   color: #000000;
# }
# #T_3fe9d_row2_col4, #T_3fe9d_row4_col2 {
#   background-color: #b82531;
#   color: #f1f1f1;
# }
# #T_3fe9d_row2_col6, #T_3fe9d_row6_col2 {
#   background-color: #ce4f45;
#   color: #f1f1f1;
# }
# #T_3fe9d_row2_col7, #T_3fe9d_row7_col2 {
#   background-color: #307ab6;
#   color: #f1f1f1;
# }
# #T_3fe9d_row2_col8, #T_3fe9d_row8_col2 {
#   background-color: #d6604d;
#   color: #f1f1f1;
# }
# #T_3fe9d_row2_col9, #T_3fe9d_row9_col2 {
#   background-color: #bf3338;
#   color: #f1f1f1;
# }
# #T_3fe9d_row2_col10, #T_3fe9d_row10_col2 {
#   background-color: #f5a886;
#   color: #000000;
# }
# #T_3fe9d_row2_col11, #T_3fe9d_row5_col10, #T_3fe9d_row10_col5, #T_3fe9d_row11_col2 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_3fe9d_row2_col12, #T_3fe9d_row6_col12, #T_3fe9d_row12_col2, #T_3fe9d_row12_col6 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
# }
# #T_3fe9d_row2_col13, #T_3fe9d_row13_col2 {
#   background-color: #71b0d3;
#   color: #f1f1f1;
# }
# #T_3fe9d_row3_col4, #T_3fe9d_row3_col5, #T_3fe9d_row3_col6, #T_3fe9d_row4_col3, #T_3fe9d_row5_col3, #T_3fe9d_row6_col3 {
#   background-color: #faeae1;
#   color: #000000;
# }
# #T_3fe9d_row3_col7, #T_3fe9d_row7_col3 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_3fe9d_row3_col8, #T_3fe9d_row8_col3 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_3fe9d_row3_col9, #T_3fe9d_row9_col3 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_3fe9d_row3_col10, #T_3fe9d_row10_col3 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_3fe9d_row3_col11, #T_3fe9d_row11_col3 {
#   background-color: #f9f0eb;
#   color: #000000;
# }
# #T_3fe9d_row3_col12, #T_3fe9d_row12_col3 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_3fe9d_row4_col5, #T_3fe9d_row5_col4 {
#   background-color: #b1d5e7;
#   color: #000000;
# }
# #T_3fe9d_row4_col6, #T_3fe9d_row6_col4 {
#   background-color: #be3036;
#   color: #f1f1f1;
# }
# #T_3fe9d_row4_col7, #T_3fe9d_row7_col4 {
#   background-color: #266caf;
#   color: #f1f1f1;
# }
# #T_3fe9d_row4_col8, #T_3fe9d_row8_col4 {
#   background-color: #d35a4a;
#   color: #f1f1f1;
# }
# #T_3fe9d_row4_col10, #T_3fe9d_row10_col4 {
#   background-color: #fddcc9;
#   color: #000000;
# }
# #T_3fe9d_row4_col12, #T_3fe9d_row12_col4 {
#   background-color: #d7634f;
#   color: #f1f1f1;
# }
# #T_3fe9d_row4_col13, #T_3fe9d_row13_col4 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_3fe9d_row5_col6, #T_3fe9d_row6_col5 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_3fe9d_row5_col7, #T_3fe9d_row7_col5 {
#   background-color: #fdd9c4;
#   color: #000000;
# }
# #T_3fe9d_row5_col8, #T_3fe9d_row8_col5 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_3fe9d_row5_col9, #T_3fe9d_row9_col5 {
#   background-color: #b3d6e8;
#   color: #000000;
# }
# #T_3fe9d_row5_col11, #T_3fe9d_row11_col5 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_3fe9d_row5_col12, #T_3fe9d_row12_col5 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_3fe9d_row5_col13, #T_3fe9d_row13_col5 {
#   background-color: #c43b3c;
#   color: #f1f1f1;
# }
# #T_3fe9d_row6_col7, #T_3fe9d_row7_col6 {
#   background-color: #2a71b2;
#   color: #f1f1f1;
# }
# #T_3fe9d_row6_col9, #T_3fe9d_row9_col6 {
#   background-color: #e48066;
#   color: #f1f1f1;
# }
# #T_3fe9d_row6_col10, #T_3fe9d_row10_col6 {
#   background-color: #facab1;
#   color: #000000;
# }
# #T_3fe9d_row6_col11, #T_3fe9d_row11_col6 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_3fe9d_row7_col8, #T_3fe9d_row7_col12, #T_3fe9d_row8_col7, #T_3fe9d_row12_col7 {
#   background-color: #6bacd1;
#   color: #f1f1f1;
# }
# #T_3fe9d_row7_col10, #T_3fe9d_row10_col7 {
#   background-color: #c7e0ed;
#   color: #000000;
# }
# #T_3fe9d_row7_col13, #T_3fe9d_row13_col7 {
#   background-color: #fbceb7;
#   color: #000000;
# }
# #T_3fe9d_row8_col9, #T_3fe9d_row9_col8 {
#   background-color: #870a24;
#   color: #f1f1f1;
# }
# #T_3fe9d_row8_col10, #T_3fe9d_row10_col8 {
#   background-color: #ea8e70;
#   color: #f1f1f1;
# }
# #T_3fe9d_row8_col11, #T_3fe9d_row9_col11, #T_3fe9d_row11_col8, #T_3fe9d_row11_col9 {
#   background-color: #81bad8;
#   color: #000000;
# }
# #T_3fe9d_row8_col12, #T_3fe9d_row12_col8 {
#   background-color: #e6866a;
#   color: #f1f1f1;
# }
# #T_3fe9d_row9_col12, #T_3fe9d_row12_col9 {
#   background-color: #de735c;
#   color: #f1f1f1;
# }
# #T_3fe9d_row9_col13, #T_3fe9d_row13_col9 {
#   background-color: #78b4d5;
#   color: #000000;
# }
# #T_3fe9d_row10_col11, #T_3fe9d_row11_col10 {
#   background-color: #d5e7f1;
#   color: #000000;
# }
# #T_3fe9d_row10_col12, #T_3fe9d_row12_col10 {
#   background-color: #f5ac8b;
#   color: #000000;
# }
# #T_3fe9d_row10_col13, #T_3fe9d_row13_col10 {
#   background-color: #68abd0;
#   color: #f1f1f1;
# }
# #T_3fe9d_row11_col12, #T_3fe9d_row12_col11 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_3fe9d_row11_col13, #T_3fe9d_row13_col11 {
#   background-color: #f7b799;
#   color: #000000;
# }
# #T_3fe9d_row12_col13, #T_3fe9d_row13_col12 {
#   background-color: #2b73b3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3fe9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fe9d_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_3fe9d_l

# %%
"""
Scatter plot for each feature vs target(=MEDV)
"""

fig, axes = plt.subplots(2, 7)
cols = data.columns
for i, col in enumerate(cols[:-1]):
    rn, cn = divmod(i, 7)
    ax = axes[rn, cn]
    ax = sns.regplot(data=data, x=col, y="MEDV", ax=ax, scatter_kws={"s": 0.7}, line_kws={"color": "blue", "linewidth": 1})
    ax.grid(linestyle=":")
    ax.set_xlabel(col)
    ax.set_ylabel("MEDV")

axes[-1, -1].axis("off")

fig.subplots_adjust(right=2, wspace=0.7, hspace=0.5)

# %% [markdown]
# ## Preprocess Dataset

# %%
feature_cols = data.columns[:-1].tolist()
y_col = data.columns[-1]

print(feature_cols)
print(y_col)
# Out:
# ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# MEDV

# %%
X_raw = data.iloc[:, :-1].values
y_raw = data.iloc[:, -1].values

# %%
X_raw.shape
# Out:
# (506, 13)

# %%
y_raw.shape
# Out:
# (506,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_raw, y_raw, test_size=0.2, random_state=42)

print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# X_train: (404, 13)
# y_train: (404,)
# X_test: (102, 13)
# y_test: (102,)

# %% [markdown]
# ## Train Model

# %%
model = xgboost.XGBRegressor(objective="reg:linear")
model.fit(X_train, y_train)
# Out:
# [12:22:58] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, objective='reg:linear', ...)

# %%
pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

mse_train = mean_squared_error(y_train, pred_train)
mse_test = mean_squared_error(y_test, pred_test)

print(f"RMSE Train: {mse_train**(1/2.):.2f}")
print(f"RMSE Test: {mse_test**(1/2.):.2f}")
# Out:
# RMSE Train: 0.02
# RMSE Test: 2.63

# %% [markdown]
# ## Model Interpretation

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_train)

# %%
"""
'force_plot' visualizes the given SHAP values with an additive force layout

Prediction: 11.99
Contribution for each feature
- Features marked in red colored text have positive effect on house price
- Features marked in blue colored text have negative effect on house price
"""

idx = 0

shap.force_plot(
    explainer.expected_value,
    shap_values=shap_values[idx, :],
    features=X_train[idx, :],
    feature_names=feature_cols
)
# Out:
# <div id='iIL35RRHQPPKG75GFCYFB'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 22.796524047851562, "outValue": 11.990930557250977, "link": "identity", "featureNames": ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT"], "features": {"0": {"effect": -0.4275752902030945, "value": 15.0234}, "1": {"effect": -0.013865816406905651, "value": 0.0}, "2": {"effect": -0.047447629272937775, "value": 18.1}, "3": {"effect": -0.010049881413578987, "value": 0.0}, "4": {"effect": 0.6569977402687073, "value": 0.614}, "5": {"effect": -2.085905075073242, "value": 5.304}, "6": {"effect": -0.6280834674835205, "value": 97.3}, "7": {"effect": 0.39936622977256775, "value": 2.1007}, "8": {"effect": 0.02313871681690216, "value": 24.0}, "9": {"effect": -0.1689639538526535, "value": 666.0}, "10": {"effect": -0.28531721234321594, "value": 20.2}, "11": {"effect": 0.06429139524698257, "value": 349.48}, "12": {"effect": -8.282179832458496, "value": 24.91}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iIL35RRHQPPKG75GFCYFB')
#   );
# </script>

# %%
"""
Also can be displayed with matplotlib
"""

shap.force_plot(
    explainer.expected_value,
    shap_values=shap_values[idx, :],
    feature_names=X_train[idx, :],
    matplotlib=True,
)

# %%
shap.force_plot(
    explainer.expected_value,
    shap_values=shap_values[:5, :],
    features=X_train[:5, :],
    feature_names=feature_cols,
    matplotlib=False
)
# Out:
# <div id='iPKPVGMDQGH562ZMLRORT'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 22.796524047851562, "link": "identity", "featureNames": ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT"], "explanations": [{"outValue": 11.990930557250977, "simIndex": 1.0, "features": {"0": {"effect": -0.4275752902030945, "value": 15.0234}, "1": {"effect": -0.013865816406905651, "value": 0.0}, "2": {"effect": -0.047447629272937775, "value": 18.1}, "3": {"effect": -0.010049881413578987, "value": 0.0}, "4": {"effect": 0.6569977402687073, "value": 0.614}, "5": {"effect": -2.085905075073242, "value": 5.304}, "6": {"effect": -0.6280834674835205, "value": 97.3}, "7": {"effect": 0.39936622977256775, "value": 2.1007}, "8": {"effect": 0.02313871681690216, "value": 24.0}, "9": {"effect": -0.1689639538526535, "value": 666.0}, "10": {"effect": -0.28531721234321594, "value": 20.2}, "11": {"effect": 0.06429139524698257, "value": 349.48}, "12": {"effect": -8.282179832458496, "value": 24.91}}}, {"outValue": 19.91550064086914, "simIndex": 4.0, "features": {"0": {"effect": 0.5988190174102783, "value": 0.62739}, "1": {"effect": -0.014577466994524002, "value": 0.0}, "2": {"effect": -0.07746487855911255, "value": 8.14}, "3": {"effect": -0.011341460980474949, "value": 0.0}, "4": {"effect": -0.0286459531635046, "value": 0.538}, "5": {"effect": -3.889404535293579, "value": 5.834}, "6": {"effect": 0.2648221254348755, "value": 56.5}, "7": {"effect": -0.41722437739372253, "value": 4.4986}, "8": {"effect": 0.07628180831670761, "value": 4.0}, "9": {"effect": -0.1176537275314331, "value": 307.0}, "10": {"effect": -1.1276822090148926, "value": 21.0}, "11": {"effect": 0.09202791005373001, "value": 395.62}, "12": {"effect": 1.7710204124450684, "value": 8.47}}}, {"outValue": 19.392982482910156, "simIndex": 5.0, "features": {"0": {"effect": -0.1219429075717926, "value": 0.03466}, "1": {"effect": 0.15615126490592957, "value": 35.0}, "2": {"effect": 0.07361927628517151, "value": 6.06}, "3": {"effect": -0.00801160093396902, "value": 0.0}, "4": {"effect": 0.16443446278572083, "value": 0.4379}, "5": {"effect": -4.110907554626465, "value": 6.031}, "6": {"effect": 1.147984504699707, "value": 23.3}, "7": {"effect": -0.7917846441268921, "value": 6.6407}, "8": {"effect": -0.8342179656028748, "value": 1.0}, "9": {"effect": -0.421169251203537, "value": 304.0}, "10": {"effect": 0.2783779203891754, "value": 16.9}, "11": {"effect": -0.08962207287549973, "value": 362.25}, "12": {"effect": 1.1535470485687256, "value": 7.83}}}, {"outValue": 13.408073425292969, "simIndex": 2.0, "features": {"0": {"effect": -0.12092452496290207, "value": 7.05042}, "1": {"effect": -0.013522048480808735, "value": 0.0}, "2": {"effect": -0.03434978052973747, "value": 18.1}, "3": {"effect": -0.01721271499991417, "value": 0.0}, "4": {"effect": 0.36567845940589905, "value": 0.614}, "5": {"effect": -1.4647150039672852, "value": 6.103}, "6": {"effect": -0.13482455909252167, "value": 85.1}, "7": {"effect": 0.403728187084198, "value": 2.0218}, "8": {"effect": 0.016685867682099342, "value": 24.0}, "9": {"effect": -0.17998673021793365, "value": 666.0}, "10": {"effect": -0.4213733971118927, "value": 20.2}, "11": {"effect": -0.3471669554710388, "value": 2.52}, "12": {"effect": -7.440467834472656, "value": 23.29}}}, {"outValue": 18.190977096557617, "simIndex": 3.0, "features": {"0": {"effect": 0.5810983777046204, "value": 0.7258}, "1": {"effect": -0.00997191108763218, "value": 0.0}, "2": {"effect": -0.13117772340774536, "value": 8.14}, "3": {"effect": -0.01058247685432434, "value": 0.0}, "4": {"effect": 0.2101353108882904, "value": 0.538}, "5": {"effect": -3.5311851501464844, "value": 5.727}, "6": {"effect": 0.2105022519826889, "value": 69.5}, "7": {"effect": -0.24323230981826782, "value": 3.7965}, "8": {"effect": -0.13047249615192413, "value": 4.0}, "9": {"effect": -0.2046843022108078, "value": 307.0}, "10": {"effect": -1.093503713607788, "value": 21.0}, "11": {"ef ...
#     document.getElementById('iPKPVGMDQGH562ZMLRORT')
#   );
# </script>
